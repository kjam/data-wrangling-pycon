# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import Spectral6

# %%
df = pd.read_csv('../../data/imf_indicators.tsv', delimiter='\t', thousands=',', na_values=['n/a'])

# %%
df.head()
# Out:
#      Country                       Subject Descriptor              Units  \
# 0  Australia  Gross domestic product, constant prices  National currency
# 1  Australia  Gross domestic product, constant prices     Percent change
# 2  Australia   Gross domestic product, current prices  National currency
# 3  Australia   Gross domestic product, current prices       U.S. dollars
# 4  Australia         Gross domestic product, deflator              Index
#
#       Scale                      Country/Series-specific Notes      2013  \
# 0  Billions  Source: National Statistical Office. Australia...  1536.590
# 1       NaN  See notes for:  Gross domestic product, consta...     2.057
# 2  Billions  Source: National Statistical Office. Australia...  1550.849
# 3  Billions  See notes for:  Gross domestic product, curren...  1501.883
# 4       NaN  See notes for:  Gross domestic product, consta...   100.928
#
#        2014      2015      2016      2017      2018       2019      2020  \
# 0  1578.223  1623.128  1674.434  1726.493  1777.878  1,829.250  1880.954
# 1     2.709     2.845     3.161     3.109     2.976      2.890     2.827
# 2  1599.790  1615.125  1689.035  1768.623  1853.075  1,950.376  2052.622
# 3  1444.189  1252.273  1281.729  1323.938  1370.832  1,427.612  1490.895
# 4   101.367    99.507   100.872   102.440   104.230    106.622   109.127
#
#    Estimates Start After
# 0                 2014.0
# 1                 2014.0
# 2                 2014.0
# 3                 2014.0
# 4                 2014.0

# %%
df['Subject Descriptor'].value_counts()
# Out:
# General government gross debt                                                             74
# Inflation, end of period consumer prices                                                  74
# Gross domestic product, current prices                                                    74
# General government total expenditure                                                      74
# Gross domestic product per capita, current prices                                         74
# General government net lending/borrowing                                                  74
# Inflation, average consumer prices                                                        74
# General government revenue                                                                74
# General government net debt                                                               74
# General government structural balance                                                     74
# General government primary net lending/borrowing                                          74
# Current account balance                                                                   74
# Gross domestic product, constant prices                                                   74
# Volume of exports of goods and services                                                   37
# Volume of imports of goods and services                                                   37
# Six-month London interbank offered rate (LIBOR)                                           37
# Gross domestic product based on purchasing-power-parity (PPP) per capita GDP              37
# Volume of Imports of goods                                                                37
# Total investment                                                                          37
# Employment                                                                                37
# Unemployment rate                                                                         37
# Gross domestic product based on purchasing-power-parity (PPP) share of world total        37
# Volume of exports of goods                                                                37
# Output gap in percent of potential GDP                                                    37
# Gross national savings                                                                    37
# Population                                                                                37
# Gross domestic product per capita, constant prices                                        37
# Implied PPP conversion rate                                                               37
# Gross domestic product based on purchasing-power-parity (PPP) valuation of country GDP    37
# Gross domestic product corresponding to fiscal year, current prices                       37
# Gross domestic product, deflator                                                          37
# Name: Subject Descriptor, dtype: int64

# %%
def mscatter(chart, x, y, typestr):
    chart.scatter(x, y, marker=typestr, line_color="#6666ee",
                  fill_color="#ee6666", fill_alpha=0.5, size=12)

# %%
def draw_scatter(df):
    chart = figure(title="IMF Unemployment")
    output_notebook()
    for year in ['2013', '2014', '2015', '2016']:
        df[year].map(lambda x: mscatter(chart, int(year), x, 'circle'))
    return chart

# %%
chart = draw_scatter(df[df['Subject Descriptor'] == 'Unemployment rate'])
show(chart)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b81af8ef-47a3-40fb-851f-427afee5f91c">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="2243ff3c-503a-4ab8-b5ab-d220eab3e915"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2243ff3c-503a-4ab8-b5ab-d220eab3e915");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2243ff3c-503a-4ab8-b5ab-d220eab3e915' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0d056b59-b7a6-4ecb-b0a6-c7b26d478f81":{"roots":{"references":[{"attributes":{"callback":null},"id":"f1bda795-61ac-4b8d-bd00-3b0fef9db84a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"value":2014},"y":{"value":1.95}},"id":"e8f195c7-f56a-4766-9213-8456f5b0e821","type":"Circle"},{"attributes":{"data_source":{"id":"89f84d24-a0d6-49ad-82d9-86f572e94c71","type":"ColumnDataSource"},"glyph":{"id":"3dc5e284-31c2-4cdf-96d5-7910cbf8f5a8","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"5df3c1d9-c0db-404b-86a2-b1c889000572","type":"Circle"},"selection_glyph":null},"id":"e902cbca-0951-4b29-9016-4ca1946bd3c1","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"607913aa-e40f-4d83-ac61-cf631a76fbf0","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"646f69b0-0716-43e5-85a2-364b6617c038","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"f1b9051c-0c2c-498a-9bba-5f6013c2efcd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#ee6666"},"line_color":{"value":"#6666ee"},"size":{"units":"screen","value":12},"x":{"value":2015},"y":{"value":8.4}},"id":"0680ff91-c2fd-4fe5-8697-db84c2a5a48d","type":"Circle"},{"attributes":{"callback":null},"id":"15b72be4-ef30-45ff-886f-ea3bc79b581a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3317e614-d2be-4b0a-aeb6-767e38f926ee","type":"ColumnDataSource"},"glyph":{"id":"e7f8c330-7d08-446a-a497-277855ebc22c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"07acf35e-0148-4aec-af09-73bf02bc6f63","type":"Circle"},"selection_glyph":null},"id":"50430819-6abe-410b-ba8e-f26d5d3b21f2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"value":2013},"y":{"value":3.125}},"id":"ea124f30-102a-4673-81e8-095cd8a9eee9","type":"Circle"},{"attributes":{"callback":null},"id":"2f001c0f-2b39-4ffc-983d-321d48ea2ef9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"value":2016},"y":{"value":22.121}},"id":"d503315c-c9af-4745-b031-e69d66b22c37","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#ee6666"},"line_color":{"value":"#6666ee"},"size":{"units":"screen","value":12},"x":{"value":2015},"y":{"value":8.713}},"id":"d4b6f77a-8db8-4fb5-96cd-785a4f063803","type":"Circle"},{"attributes":{"callback":null},"id":"52410730-ac33-4f74-b1c6-2993f9a2cde4","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"72ee7f82-6caa-4315-9578-9b59c085c91b","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"ba16ec47-650a-47ad-ae77-1683ae4afabb","type":"ColumnDataSource"},{"attributes":{},"id":"c57f4cf2-ce16-4237-a4a0-e202fb4606bf","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"365ea3e4-d741-424b-a244-50cace3ddda0","type":"ColumnDataSource"},"glyph":{"id":"dce3b72f-99d6-43fc-8304-96dd23ceb641","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"3febdb2c-fff5-4e0c-ade3-2182a09c9a3c","type":"Circle"},"selection_glyph":null},"id":"5c76729c-dbc5-4675-a041-fdcafd21ea3d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"value":2016},"y":{"value":8.842}},"id":"433ac048-eab9-4855-b579-d1d0d601f324","type":"Circle"},{"attributes":{"callback":null},"id":"5c2efaa4-b562-49a7-bc59-2007bbfcf912","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#ee6666"},"line_color":{"value":"#6666ee"},"si ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[21]</strong>&gt;</code></p>

# %%
grouped_mean_df = df[df['Subject Descriptor'] == 'Unemployment rate'].groupby(
    'Country')[['2013', '2014', '2015', '2016']].mean()

# %%
grouped_mean_df.head()
# Out:
#              2013    2014    2015    2016
# Country
# Australia   5.658   6.067   6.400   6.200
# Austria     4.917   5.000   5.100   5.000
# Belgium     8.408   8.492   8.400   8.208
# Canada      7.083   6.917   6.988   6.930
# Cyprus     15.917  16.170  15.905  14.916

# %%
def draw_line(df):
    chart = figure(title="IMF Unemployment")
    output_notebook()
    color_count = 0
    for country, data in df.iterrows():
        chart.line(data.index.values, data.values, legend=country, line_color=Spectral6[color_count])
        if color_count+1 != len(Spectral6):
            color_count += 1
        else:
            color_count = 0
    return chart

# %%
chart = draw_line(grouped_mean_df)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="95ce9c4a-7db5-4461-a829-ff6df665f5d6">Loading BokehJS ...</span>
#     </div>

# %%
show(chart)
# Out:
#     <div class="plotdiv" id="3fc98619-7d7b-462e-aace-d61983c60409"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3fc98619-7d7b-462e-aace-d61983c60409");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3fc98619-7d7b-462e-aace-d61983c60409' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"94f607dd-5f69-4490-8d45-c6506bf3c2a8":{"roots":{"references":[{"attributes":{"callback":null},"id":"f1bda795-61ac-4b8d-bd00-3b0fef9db84a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"value":2014},"y":{"value":1.95}},"id":"e8f195c7-f56a-4766-9213-8456f5b0e821","type":"Circle"},{"attributes":{"data_source":{"id":"89f84d24-a0d6-49ad-82d9-86f572e94c71","type":"ColumnDataSource"},"glyph":{"id":"3dc5e284-31c2-4cdf-96d5-7910cbf8f5a8","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"5df3c1d9-c0db-404b-86a2-b1c889000572","type":"Circle"},"selection_glyph":null},"id":"e902cbca-0951-4b29-9016-4ca1946bd3c1","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#3288bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0a54f97b-1c1d-4643-8ad1-9a36158d8d1a","type":"Line"},{"attributes":{"callback":null},"id":"607913aa-e40f-4d83-ac61-cf631a76fbf0","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"646f69b0-0716-43e5-85a2-364b6617c038","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4a6ea881-f20e-4783-a60c-18b1abfd9257","type":"ColumnDataSource"},"glyph":{"id":"bed12608-4837-4153-b68e-6f1c6a79c235","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"871e1d88-4a58-46e3-b61f-d0343dc09bd2","type":"Circle"},"selection_glyph":null},"id":"090fc27f-b250-4b39-a977-a6e631d383f7","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#ee6666"},"line_color":{"value":"#6666ee"},"size":{"units":"screen","value":12},"x":{"value":2015},"y":{"value":8.4}},"id":"0680ff91-c2fd-4fe5-8697-db84c2a5a48d","type":"Circle"},{"attributes":{"callback":null},"id":"15b72be4-ef30-45ff-886f-ea3bc79b581a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3317e614-d2be-4b0a-aeb6-767e38f926ee","type":"ColumnDataSource"},"glyph":{"id":"e7f8c330-7d08-446a-a497-277855ebc22c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"07acf35e-0148-4aec-af09-73bf02bc6f63","type":"Circle"},"selection_glyph":null},"id":"50430819-6abe-410b-ba8e-f26d5d3b21f2","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1a4bc783-6c8d-47e6-8a0f-a3cb79f86e78","type":"ColumnDataSource"},"glyph":{"id":"6856e22f-fccf-4145-97a6-0413a67b826a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f280d035-805a-4d22-92d6-2e127cc93caa","type":"Line"},"selection_glyph":null},"id":"ee5366db-8bf8-4fe6-beb8-e18dcaaba91e","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"bd2cfb9b-2064-4bf0-91b9-5a08b0c1e553","subtype":"Figure","type":"Plot"}},"id":"3325571a-4bad-4cbf-ad70-0a778f004453","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"value":2013},"y":{"value":3.125}},"id":"ea124f30-102a-4673-81e8-095cd8a9eee9","type":"Circle"},{"attributes":{"callback":null},"id":"2f001c0f-2b39-4ffc-983d-321d48ea2ef9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"value":2016},"y":{"value":22.121}},"id":"d503315c-c9af-4745-b031-e69d66b22c37","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#ee6666"},"line_color":{"value":"#6666ee"},"size":{"units":"screen","value":12},"x":{"value":2015},"y":{"value":8.713}},"id":"d4b6f77a-8db8-4fb5-96cd-785a4f063803","type":"Circle"},{"attributes":{"callback":null},"id":"52410730-ac33-4f74-b1c6-2993f9a2cde4","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"95eb81a3-49e5-4728-8763-92fd8bd68a6b","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fil ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[69]</strong>&gt;</code></p>

# %% [markdown]
# ### Can you rewrite this to show a reasonable number of countries (focus on between four to seven)
